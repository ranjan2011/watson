# %% [markdown]
# *Audience interest in different data science topics*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#                          type  Very interested  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)             1332                  729
# 1  Data Analysis / Statistics             1688                  444
# 2             Data Journalism              429                 1081
# 3          Data Visualization             1340                  734
# 4               Deep Learning             1263                  770
#
#    Not interested
# 0             127
# 1              60
# 2             610
# 3             102
# 4             136

# %%
df_data = df_data_0.set_index(df_data_0.iloc[:, 0])

# %%
df_data.drop(df_data.columns[[0]], axis = 1, inplace = True)

# %%
df_data
# Out:
#                             Very interested  Somewhat interested  \
# type
# Big Data (Spark / Hadoop)              1332                  729
# Data Analysis / Statistics             1688                  444
# Data Journalism                         429                 1081
# Data Visualization                     1340                  734
# Deep Learning                          1263                  770
# Machine Learning                       1629                  477
#
#                             Not interested
# type
# Big Data (Spark / Hadoop)              127
# Data Analysis / Statistics              60
# Data Journalism                        610
# Data Visualization                     102
# Deep Learning                          136
# Machine Learning                        74

# %%
df_data.plot(kind='bar')
plt.ylabel('number')
plt.title('percentage of respondeant interest in data science')
plt.show()

# %%
import matplotlib as mpl
mpl.style.use('ggplot')

# %matplotlib inline

# %%
df_data.sort_values(['Very interested'], ascending=False, axis=0, inplace=True)
df_data_pct = ((df_data / 2233) * 100).round(2)
ax = df_data_pct.plot(kind='bar',
                       figsize = (20, 8),
                       width = 0.8,
                       color = ['#5cb85c', '#5bc0de', '#d9534f'],
                       fontsize = 14)
plt.title('Percentage of Respondents Interests\''' in Data Science Areas', fontsize=16)
ax.set_facecolor((1.0, 1.0, 1.0))
y_axis = ax.axes.get_yaxis()
y_axis.set_visible(False)
for p in ax.patches:
    ax.annotate(str(p.get_height()) + '%', (p.get_x() * 1.005, p.get_height() * 1.03))
    
plt.show()

# %%
df_sfcrime = pd.read_csv("https://cocl.us/sanfran_crime_dataset")

# %%
df_tmp = df_sfcrime.groupby(['PdDistrict']).count().reset_index()
df_tmp.drop(['Category','Descript','DayOfWeek','Date','Time', 'Resolution','Address','X','Y','Location','PdId'], axis=1, inplace=True)
df_tmp.rename(columns={'PdDistrict':'Neighborhood', 'IncidntNum':'Count'}, inplace=True)

# %%
df_tmp
# Out:
#   Neighborhood  Count
# 0      BAYVIEW  14303
# 1      CENTRAL  17666
# 2    INGLESIDE  11594
# 3      MISSION  19503
# 4     NORTHERN  20100
# 5         PARK   8699
# 6     RICHMOND   8922
# 7     SOUTHERN  28445
# 8      TARAVAL  11325
# 9   TENDERLOIN   9942

# %%
import folium
sf_map = folium.Map(location=[37.773972, -122.431297], zoom_start=12) #, tiles='Mapbox Bright')
sf_map.choropleth(
    geo_data=sf_geo,
    data=df_tmp,
    columns=['Neighborhood','Count'],
    key_on='feature.properties.DISTRICT',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='San Francisco Crimes'
)

# display map
sf_map
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-768a2afbe662> in <module>
# ----> 1 import folium
#       2 sf_map = folium.Map(location=[37.773972, -122.431297], zoom_start=12) #, tiles='Mapbox Bright')
#       3 sf_map.choropleth(
#       4     geo_data=sf_geo,
#       5     data=df_tmp,
#
# ModuleNotFoundError: No module named 'folium'

# %%
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-173c1173bf1c> in <module>
# ----> 1 import folium
#
# ModuleNotFoundError: No module named 'folium'
